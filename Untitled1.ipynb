# %%
import matplotlib.pyplot as plt
# line 1 points
x1 = [1,2,3,4,5]
y1 = [2,4,1,3,5]
# plotting the line 1 points
plt.plot(x1, y1, label = "line 1")
# line 2 points
x2 = [1,2,3,4,5]
y2 = [4,1,3,2,5]
# plotting the line 2 points
plt.plot(x2, y2, label = "line 2")
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
# giving a title to my graph
plt.title('Two lines on same plot')
# show a legend on the plot
plt.legend()
# function to show the plot
plt.show()

# %%
# importing the required modules
import matplotlib.pyplot as plt
import numpy as np
# setting the x - coordinates
x = np.arange(0, 2*(np.pi), 0.1)
# setting the corresponding y - coordinates
y = np.sin(x)
# potting the points
plt.plot(x, y, label ='sin(x)',lw=5)
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y(x)=sin(x)')
# giving a title to my graph
plt.title('Sine curve')
# show a legend on the plot
plt.legend()
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
# line 1 points
x1 = [1,2,3,4,5]
y1 = [2,4,1,3,5]
# plotting the line 1 points
plt.plot(x1, y1, label = "line 1",color='red')
# line 2 points
x2 = [1,2,3,4,5]
y2 = [4,1,3,2,5]
# plotting the line 2 points
plt.plot(x2, y2, label = "line 2")
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
# giving a title to my graph
plt.title('Two lines on same plot')
# show a legend on the plot
plt.legend()
# function to show the plot
plt.show()

# %%
# importing the module
import matplotlib.pyplot as plt
# x axis values
x = [1,2,3,4,5]
# corresponding y axis values
y = [2,4,1,3,5]
# plotting the points
plt.plot(x, y,color='orange',lw=2,linestyle='dotted')
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
# Title to plot
plt.title('Plot 2.2')
# function to show the plot
plt.show()

# %%
data = {'a': np.arange(100),
'c': np.random.randint(0, 100, 100),
'd': np.random.randn(100)}
data['b'] = data['a'] + 10 * np.random.randn(100)
data['d'] = np.abs(data['d']) * 100
#scatter plot
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
### importing libraries
import matplotlib.pyplot as plt
import numpy as np
## setting the x - coordinates
n = np.linspace(0.1, 14, 15)
# calculating corresponding the y - coordinates
xn = (np.sin(2*n*(np.pi)/15))
# plotting the points
plt.stem(n, xn, use_line_collection = True)
# naming the x axis
plt.xlabel('n (samples)')
# naming the y axis
plt.ylabel('x[n]')
# giving a title to my graph
plt.title('DT Sine curve')
#showing the plot
plt.show()
# Out:
# <ipython-input-16-561b22f8fc3b>:9: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n, xn, use_line_collection = True)

# %%
def add_num(a,b):
  sum=a+b;
  return sum;
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
print("Sum of the numbers is: ",add_num(num1,num2))
# Out:
# Enter the first number: 14.6
# Enter the second number: 15.2
# Sum of the numbers is:  29.799999999999997
